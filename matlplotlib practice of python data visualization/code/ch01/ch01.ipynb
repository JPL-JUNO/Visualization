# %%
print("""
@Description: 使用函数绘制 matplotlib 的图表组成元素
@Author(s): Stephen CUI
@LastEditor(s): Stephen CUI
@CreatedTime: 2023-08-15 16:48:45
""")
# Out:
# @Description: 使用函数绘制 matplotlib 的图表组成元素
# @Author(s): Stephen CUI
# @LastEditor(s): Stephen CUI
# @CreatedTime: 2023-08-15 16:48:45

# %% [markdown]
# # 使用函数绘制 matplotlib 的图表组成元素

# %% [markdown]
# ## 准备数据

# %%
import numpy as np
import matplotlib.pyplot as plt
# 函数 linspace(0.5,3.5,100) 是表示在 0.5 至 3.5 之间均匀地取 100 个数
x = np.linspace(.5, 3.5, 100)
y = np.sin(x)
# 函数 randn(100) 表示在标准正态分布中随机地取 100 个数。
y1 = np.random.randn(1000)

# %% [markdown]
# ## 绘制 matplotlib 图表组成元素的函数用法

# %% [markdown]
# ### 函数 plot()——展现变量的趋势变化
# 函数功能：展现变量的趋势变化。
#
# 调用签名：``plt.plot(x,y,ls="-",lw=2,label="plot figure")``
#
# 参数说明
# - x：x 轴上的数值。
# - y：y 轴上的数值。
# - ls：折线图的线条风格。
# - lw：折线图的线条宽度。
# - label：标记图形内容的标签文本。

# %%
plt.plot(x, y, ls='-', lw=2, label='plot figure')
plt.legend()
plt.show()

# %% [markdown]
# ### 函数 scatter()——寻找变量之间的关系

# %% [markdown]
# 函数功能：寻找变量之间的关系。
#
# 调用签名：``plt.scatter(x,y1,c="b",label="scatter figure")``
#
# 参数说明
# - x：x 轴上的数值。
# - y：y 轴上的数值。
# - c：散点图中的标记的颜色。
# - label：标记图形内容的标签文本。

# %%
plt.scatter(x, y, c='red', s=2, label='scatter figure')
plt.legend()
plt.show()

# %% [markdown]
# ### 函数 xlim()——设置 x 轴的数值显示范围

# %% [markdown]
# 函数功能：设置 x 轴的数值显示范围。
#
# 调用签名：``plt.xlim(xmin, xmax)``
#
# 参数说明
# - xmin：x 轴上的最小值。
# - xmax：x 轴上的最大值。
# - 平移性：上面的函数功能，调用签名和参数说明同样可以平移到函数 ylim()上。

# %%
plt.plot(x, y, label='plot figure')
plt.xlim(.05, 5)
plt.legend()
plt.show()

# %% [markdown]
# ### 函数 xlabel()——设置 x 轴的标签文本
# 函数功能：设置 x 轴的标签文本。
#
# 调用签名：``plt.xlabel(string)``
#
# 参数说明
# - string：标签文本内容。
# - 平移性：上面的函数功能，调用签名和参数说明同样可以平移到函数 ylabel()上。

# %%
plt.plot(x, y, ls='-', lw=2, c='c', label='show xlabel')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()

# %% [markdown]
# ### 函数 grid()——绘制刻度线的网格线
# 函数功能：绘制刻度线的网格线。
#
# 调用签名：``plt.grid(linestyle=":",color="r")``
#
# 参数说明
# - linestyle：网格线的线条风格。
# - color：网格线的线条颜色。

# %%
plt.plot(x, y, label='show grid')
plt.grid(linestyle=':', color='r')
plt.legend()
plt.show()

# %% [markdown]
# ### 函数 axhline()——绘制平行于 x 轴的水平参考线
#
# 函数功能：绘制平行于 x 轴的水平参考线。
#
# 调用签名：``plt.axhline(y=0.0,c="r",ls="--",lw=2)``
#
# 参数说明
# - y：水平参考线的出发点。
# - c：参考线的线条颜色。
# - ls：参考线的线条风格。
# - lw：参考线的线条宽度。
# - 平移性：上面的函数功能，调用签名和参数说明同样可以平移到函数 axvline()上。

# %%
plt.plot(x, y, label='axhline')
plt.axhline(y=.5, c='r', ls='--', lw=2)
plt.axvline(x=2.0, c='c', ls='-.', lw=3)
plt.legend()
plt.show()

# %% [markdown]
# ### 函数 axvspan()——绘制垂直于 x 轴的参考区域

# %% [markdown]
# 函数功能：绘制垂直于 x 轴的参考区域。
#
# 调用签名：``plt.axvspan(xmin=1.0,xmax=2.0,facecolor="y",alpha=0.3)``
#
# 参数说明
# - xmin：参考区域的起始位置。
# - xmax：参考区域的终止位置。
# - facecolor：参考区域的填充颜色。
# - alpha：参考区域的填充颜色的透明度。
# - 平移性：上面的函数功能、调用签名和参数说明可以平移到函数 axhspan()上。

# %%
plt.plot(x, y, ls='-.', lw=2, c='c', label='show axvspan')
plt.axvspan(xmin=2, xmax=3, facecolor='y', alpha=.5)
plt.axhspan(ymin=-.2, ymax=.1, facecolor='r', alpha=.3)
plt.legend()
plt.show()

# %% [markdown]
# ### 函数 annotate()——添加图形内容细节的指向型注释文本

# %% [markdown]
# 函数功能：添加图形内容细节的指向型注释文本。
#
# 调用签名：``plt.annotate(string, xy, xytext, weight, color, arrowprops=dict(arrowstyle, connectionstyle, color))``
#
# 参数说明
# - string：图形内容的注释文本。
# - xy：被注释图形内容的位置坐标。
# - xytext：注释文本的位置坐标。
# - weight：注释文本的字体粗细风格。
# - color：注释文本的字体颜色。
# - arrowprops：指示被注释内容的箭头的属性字典。

# %%
plt.plot(x, y, ls='-.', lw=2, c='c', label='show annotate')
plt.annotate('maximum', 
             xy=(np.pi/2, 1.0), 
             xytext=(np.pi/2 + 1.0, .8),
             weight='bold',
             color='b',
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='b'))
plt.legend()
plt.show()

# %% [markdown]
# ### 函数 text()——添加图形内容细节的无指向型注释文本

# %% [markdown]
# 函数功能：添加图形内容细节的无指向型注释文本。
#
# 调用签名：``plt.text(x,y,string,weight="bold",color="b")``
#
# 参数说明
# - x：注释文本内容所在位置的横坐标。
# - y：注释文本内容所在位置的纵坐标。
# - string：注释文本内容。
# - weight：注释文本内容的粗细风格。
# - color：注释文本内容的字体颜色。

# %%
plt.plot(x, y, label='show plt.text')
plt.text(2.2, .4, 'y=sin(x)', weight='bold', color='b')
plt.legend()
plt.show()

# %% [markdown]
# ### 函数 title()——添加图形内容的标题

# %% [markdown]
# 函数功能：添加图形内容的标题
#
# 调用签名：``plt.title(string)``
#
# 参数说明
# - string：图形内容的标题文本。

# %%
plt.plot(x, y, label='show plt.title')
plt.title('y=sin(x)')
plt.legend()
plt.show()

# %% [markdown]
# ### 函数 legend()——标示不同图形的文本标签图例

# %% [markdown]
# 函数功能：标示不同图形的文本标签图例。
#
# 调用签名：``plt.legend(loc="lower left")``
#
# 参数说明
# - loc：图例在图中的地理位置。

# %%
plt.plot(x, y, label='show plt.legend')
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# ## 函数组合应用

# %% [markdown]
# ![Structure of Figure](https://github.com/JPL-JUNO/Visualization/blob/main/matlplotlib%20practice%20of%20python%20data%20visualization/code/structure%20of%20matplotlib.png?raw=true)

# %% [markdown]
# [代码点击🚪](https://github.com/JPL-JUNO/Visualization/blob/main/matlplotlib%20practice%20of%20python%20data%20visualization/code/ch1_4.py)
